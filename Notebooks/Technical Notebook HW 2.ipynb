# %% [markdown]
# # Data 602 Project 2
#
# ## Abstract
#
# Using a CDC dataset containing 2019 US birth data, this project aimed to determine if there were any hidden clusters in the data, based upon demographics, prenatal characteristics, and post-natal outcomes. After initial cleaning, the dataset contained 22897669 rows and 87 Columns for a final file size of 561KB.
# Ultimately I identified <b>3 clusters, some of which overlap </b> in the data. Upon closer analysis of the differences between those clusters, I found that parental age, prior births, birth weight, maternal BMI,and parental education were among the features that most varied among groups. These data can be used to now target those populations most at risk of a negative outcome, for example, the cluster with the highest parental ages also had higher APGAR5 scores, indicating poorer health indicators for the infant after birth.
#
# ## Introduction
#
# Using a CDC dataset containing 2019 US birth data, this project aimed to fit a clustering model to identify hidden groups within the data that could benefit from intervention to prevent maternal or infant mortality and morbidity.
#
# Due to the runtimes involved I chose to use a subset of the data for the majority of data exploration so that the functions would run quickly. I used 1% or about 29k rows, selected via random sample, for this purpose.
#
# The analysis consisted of testing a KMeans algorithm before applying a DBSCAN algorithm in an attempt to find clusters in the data. I was ultimately unable to identify clusters within the data, despite attempting PCA to reduce dimensionality. I believe this is likely due to the complexity of the dataset and would recommend additional investigation using this data, particularly when additional computational resources are available.
#
# #### Research Questions/ Business Problem:
#
# The research problem posed in this project is based upon infant and maternal outcomes. Hypothetical uses for this analysis would be to target particular populations for additional car in Obstetric care, based upon hidden clusters identified based on outcome metrics and population demographics from CDC natality data. The specific questions to be addressed are:
#
# 1. Using U.S,. Natality data, specifically health metrics and pregnancy outcomes, can we identify hidden groups based on demographic characteristics that would benefit from additional care or consideration during the prenatal period?
# 2. By examining parental demographics and health metrics, are there hiden groups that have better or poorer natality outcomes? Using PCA can we identify the features that most contribute to this variation?
#
# Stakeholders in this endeavor would include the CDC and national health policy makers as well as hospital administrators and potentially even medical practitioners.
# The overall business goal of this project would be to reduce incidences of maternal and/or infant morbidity and mortality by identifying upstream population targets for intervention that can improve outcomes.
#
# The data being used to address this question has high dimensionallity and is very complicated, with multiple categorical and numeric features. This presents a problem that is suited for a Clustering Machine learning algorithm, which can identify patterns in multidimensional space that we would not otherwise be able to access.
#
# ## Data Used
#
# The raw data was acquired from the CDC public data files available here: https://www.cdc.gov/nchs/data_access/vitalstatsonline.htm
#
# This data is collected from both the mother, the Facility where birth occurred, and certificates of birth (see documentation).
#
# ##### Data Dictionary:
# The files used for this project included data from 2019 and documentation for the file can be found here: ftp://ftp.cdc.gov/pub/Health_Statistics/NCHS/Dataset_Documentation/DVS/natality/UserGuide2019-508.pdf
#
# ##### Data Description:
# The original data file was a text file containing 5gb of data, consisting of 3757582 rows of data and 228 columns. After dropping rows with missing data and duplicates, as well as unneeded columns containing duplicate data (such as multiple recodes), data flags, and imputation flags (flags for were data was imputed which is not needed in this analysis) the final dataset contained 2897669 rows and 87 columns for a final file size of 561KB.
#
# ## Motivation
#
# The motivation for this project comes from the increasing amount of reasearch showing that US Maternal and infant mortality and morbidity is higher in the US than in other similarly developed countries (Chen, et al., 2016; Singh & Stella, 2019). This trend inspired me to look for data that could be used to investigate how demographic and prenatal characteristics are distributed when examining clusters in pregnancy outcomes. This led me to the Birth Data Files from the CDC.
#
# ## Proposed Method
#
# Once the data has been cleaned I propose to prepare the data for modeling using encoding and scaling. Because the data is heterogenious, I will use the labelencoder and onehotencoder functions from sklearn on the categorical variables based on their type (labelencoder for ordered and binary categorical data and onehotencoder for the unordered categorical data)
#
# I am going to start with a KMeans to see if the data have any obvious clusters, but I think the best algoithm for this will be the DBSCAN (Density-Based Spatial Clustering of Applications with Noise) algorithm. DBSCAN uses a threshold epsilon to indicate the neighbors that are considered part of the cluster. DBSCAN corepoints (the center of the cluster) is determined by the least min_sample points (min_sample being the minimum number of neighbors required to be considered a corepoint).
#
# The reason I am focusing on DBSCAN is multimodal:
# 1. The nature of the data I am using is very large, and the DBSCAN model is capable of handling large datasets efficiently
# 2. DBSCAN handles noise, and this dataset contains a lot of noise and overlapping groups
# 3. DBSCAN is able to handle oddly shaped clusters, while other methods, like KMeans, are limited to circular clusters.
#
# Drawbacks of the DBSCAN model are that if the clusters have differing densities, they are not detected well.
#
# ### Data Cleaning
#
# Find the Data Acquisition notebook here: <a href = 'https://github.com/Jcc329/Select-the-best-Wine-Predicting-wine-quality/blob/main/Jupyter%20Notebooks/Project%201%20Initial%20Data%20Cleaning%20Updated%2010_18.ipynb'>Data Acquisition Notebook</a>
#
# Find the Data Cleaning notebook here: <a href = 'https://github.com/Jcc329/Select-the-best-Wine-Predicting-wine-quality/blob/main/Jupyter%20Notebooks/Project%201%20Initial%20Data%20Cleaning%20Updated%2010_18.ipynb'>Data Cleaning Notebook</a>
#
# ### Exploratory Data Analysis and Modeling
# Detailed exploratory analysis here: <a href = 'https://github.com/Jcc329/Select-the-best-Wine-Predicting-wine-quality/blob/main/Jupyter%20Notebooks/Project%201%20Exploratory%20Analysis%20Updated.ipynb'>Exploratory Analysis Notebook</a>
#
# For a brief review of the data exploration, including demonstrations of the models attempted, scroll down.
#
# ### Limitations and Furture Research
#
# One of the primary limitations I experienced working with this data was that my computing system had a lot of difficulty dealing with the large amount of data provided in this data source. Ultimately, I ended up sampling the data in order to perform the analysis in a reasonable amount of time without interfering with the daily use of my laptop for work. I also chose to include only the ordered categorical and numeric data in this analysis in an attempt to limit features and scope of the analysis and the computational requirements.
#
# Future analyses should expand upon my investigation with improved or expanded computational power and resources, in order to incorporate the entire dataset. Furthermore, it would be interesting to use this dataset for predictive machine learning models, in order to investigate which demographic or situational features are most predictive of adverse outcomes.
#
# ### References and Contributions
#
# Chen, A., Oster, E., & Williams, H. (2016). Why is infant mortality higher in the United States than in Europe?. American Economic Journal: Economic Policy, 8(2), 89-124.
#
# Singh, G. K., & Stella, M. Y. (2019). Infant mortality in the United States, 1915-2017: large social inequalities have persisted for over a century. International Journal of Maternal and Child Health and AIDS, 8(1), 19.
#
# I used information from
# https://www.kdnuggets.com/2019/10/right-clustering-algorithm.html,
# https://www.datanovia.com/en/lessons/dbscan-density-based-clustering-essentials/#:~:text=Two%20important%20parameters%20are%20required,neighbors%20within%20%E2%80%9Ceps%E2%80%9D%20radius and
# https://towardsdatascience.com/machine-learning-clustering-dbscan-determine-the-optimal-value-for-epsilon-eps-python-example-3100091cfbc to help me decide on the algorithm to use and to understand the rationale for the DBSCAN model.
#
# I also used the following blogs, guides, and resources to help me put together the project:
# https://www.geeksforgeeks.org/ml-one-hot-encoding-of-datasets-in-python/
# https://towardsdatascience.com/dive-into-pca-principal-component-analysis-with-python-43ded13ead21
# https://medium.com/@shritam/how-dbscan-algorithm-works-2b5bef80fb3

# %%
import pandas as pd
from pandas.plotting import scatter_matrix
import numpy as np
import matplotlib.pyplot as plt # for visualizations
import seaborn as sns #for visualizations
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder #encoder for binary and ordered categorical data
from sklearn.preprocessing import OneHotEncoder #encoder for unordered categorical data
from sklearn.compose import ColumnTransformer 
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn import metrics 
from yellowbrick.cluster import KElbowVisualizer
from sklearn.neighbors import NearestNeighbors
from sklearn.cluster import DBSCAN
import time
start_time = time.time()
# Out:
# C:\Users\15856\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:143: FutureWarning: The sklearn.metrics.classification module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
df1 = pd.read_csv('./NatalityData_cleaned_1.zip', compression = 'zip', low_memory = False)
df2 = pd.read_csv('./NatalityData_cleaned_2.zip', compression = 'zip', low_memory = False)
df3 = pd.read_csv('./NatalityData_cleaned_3.zip', compression = 'zip', low_memory = False)
df4 = pd.read_csv('./NatalityData_cleaned_3.zip', compression = 'zip', low_memory = False)


df= df1.append(df2)
df= df.append(df3)
df= df.append(df4)
df.head()
# Out:
#    Unnamed: 0  Birth Place  Maternal Age  Maternal Nativity  \
# 0           1            1            40                  2
# 1           2            1            30                  1
# 2           3            1            25                  1
# 3           5            1            30                  1
# 4           6            1            33                  1
#
#    Maternal Residence Status  Maternal Race  Maternal Hispanic Origin  \
# 0                          1             10                         0
# 1                          1              3                         0
# 2                          1              1                         0
# 3                          1              6                         0
# 4                          2              1                         0
#
#   Paternity Acknowledged  Marital Status  Maternal Education  ...  \
# 0                      X             1.0                   7  ...
# 1                      X             1.0                   5  ...
# 2                      X             1.0                   6  ...
# 3                      Y             2.0                   6  ...
# 4                      X             1.0                   6  ...
#
#    Gastroschisis  Limb Reduction Defect  Cleft lip  Cleft Palate  \
# 0              N                      N          N             N
# 1              N                      N          N             N
# 2              N                      N          N             N
# 3              N                      N          N             N
# 4              N                      N          N             N
#
#    Down Syndrome  Suspected Chromosomal Disorder  Hypospadias  \
# 0              N                               N            N
# 1              N                               N            N
# 2              N                               N            N
# 3              N                               N            N
# 4              N                               N            N
#
#    Infant Transferred  Infant Living  Infant Breastfed
# 0                   N              Y                 Y
# 1                   N              Y                 Y
# 2                   N              Y                 Y
# 3                   N              Y                 Y
# 4                   N              Y                 Y
#
# [5 rows x 88 columns]

# %%
df.drop(['Unnamed: 0'], axis = 1, inplace = True)

# %%
#I Started by identifying all the variables in my dataset and splitting them by their type
Binary_Categoricals = ['Maternal Nativity','Paternity Acknowledged', 'WIC','Pre-pregnancy Diabetes', 
                      'Gestational Diabetes', 'Pre-pregnancy Hypertension', 'Gestational Hypertension',
                      'Hypertension Eclampsia', 'Previous Preterm Birth','Infertility treatment used', 'Fertility Enhancing Drugs', 
                      'Asst. Reproductive Tech', 'Gonorrhea', 'Syphilis', 'Chlamydia', 'Hep B', 'Hep C',
                      'Successful External Cephalic Version', 'Failed Cephalic Version','Induced Labor', 'Augmented Labor', 
                      'Steroids', 'Antibiotics', 'Chorioamnionitis', 'Anesthesia','If Cesarean, Labor Attempted',
                      'Maternal Transfusion', 'Perineal Laceration', 'Ruptured Uterus', 'Unplanned Hysterectomy',
                      'Maternal admit to ICU', 'Mother Transferred','infant sex','Assisted Ventilation immediately',
                      'Assisted ventilation >6hr', 'Admission to NICU', 'Surffactant', 'Antibiotis for Newborn', 'Seizures',
                      'Anencephaly', 'Spina Bifida', 'Cyanotic Congenital Heart Disease', 'Congenital Diaphragmatic Hernia',
                      'Omphalocele', 'Gastroschisis', 'Limb Reduction Defect', 'Cleft lip', 'Cleft Palate',  'Hypospadias', 'Infant Transferred', 'Infant Living', 'Infant Breastfed']
Ordered_Categoricals = ['Maternal Education','Paternal Education','Month prenatal care Began']
Unordered_Categoricals = ['Birth Place','Marital Status','Maternal Residence Status','Maternal Race','Maternal Hispanic Origin', 
                         'Paternal Race', 'Paternal Hispanic Origin', 'Fetal Presentation at Delivery','Delivery Method',
                         'Attendant at Birth','Payment Source','Down Syndrome', 'Suspected Chromosomal Disorder']
Numeric = ['Maternal Age','Paternal Age','Prior births, now living', 'Prior births, now dead', 'Prior terminations',
          'Interval since last Live Birth (Mo)', 'Number of Prenatal Visits','Daily Cigarette use before Pregnancy', 
           'Daily Cigarette use, 1st Trimester','Daily Cigarette use, 2nd Trimester', 'Daily Cigarette use, 3rd Trimester',
          'BMI', 'Weight Gain', 'Number of Previous Cesareans','5 Minute APGAR', '10 Minute APGAR', 'Plurality (Number of Babies)',
          'Gestation Duration (wks)', 'Birth Weight (g)']

# %% [markdown]
# ## Brief Exploratory Analysis
#
# The plan for my exploratory analysis was:
# - to examine each feature and it's characteristics
# - to visualize the correlation matrix for the data to explore any related attributes.
# - drop unneccessary features based on the correlation matrix
# - to perform encoding on the necessary categorical attributes
# - to scale all attributes used in the model
# - the Kmeans and DBSPAN algorithms to find clusters in the data
# - if necessary, to apply pca for feature selection

# %%
#Examine Data:
df.describe()
# Out:
#         Birth Place  Maternal Age  Maternal Nativity  \
# count  2.897669e+06  2.897669e+06       2.897669e+06
# mean   1.030343e+00  2.911478e+01       1.199670e+00
# std    2.643085e-01  5.619508e+00       3.997527e-01
# min    1.000000e+00  1.200000e+01       1.000000e+00
# 25%    1.000000e+00  2.500000e+01       1.000000e+00
# 50%    1.000000e+00  2.900000e+01       1.000000e+00
# 75%    1.000000e+00  3.300000e+01       1.000000e+00
# max    7.000000e+00  5.000000e+01       2.000000e+00
#
#        Maternal Residence Status  Maternal Race  Maternal Hispanic Origin  \
# count               2.897669e+06   2.897669e+06              2.897669e+06
# mean                1.363486e+00   1.798051e+00              5.264211e-01
# std                 5.485371e-01   2.536718e+00              1.338907e+00
# min                 1.000000e+00   1.000000e+00              0.000000e+00
# 25%                 1.000000e+00   1.000000e+00              0.000000e+00
# 50%                 1.000000e+00   1.000000e+00              0.000000e+00
# 75%                 2.000000e+00   1.000000e+00              0.000000e+00
# max                 4.000000e+00   1.500000e+01              9.000000e+00
#
#        Marital Status  Maternal Education  Paternal Age  Paternal Race  ...  \
# count    2.897669e+06        2.897669e+06  2.897669e+06   2.897669e+06  ...
# mean     1.337364e+00        4.502044e+00  3.146946e+01   8.333212e+00  ...
# std      4.728102e-01        1.732297e+00  6.724274e+00   2.447341e+01  ...
# min      1.000000e+00        1.000000e+00  1.000000e+01   1.000000e+00  ...
# 25%      1.000000e+00        3.000000e+00  2.700000e+01   1.000000e+00  ...
# 50%      1.000000e+00        4.000000e+00  3.100000e+01   1.000000e+00  ...
# 75%      2.000000e+00        6.000000e+00  3.600000e+01   2.000000e+00  ...
# max      2.000000e+00        8.000000e+00  9.800000e+01   9.900000e+01  ...
#
#        Number of Previous Cesareans  Fetal Presentation at Delivery  \
# count                  2.897669e+06                    2.897669e+06
# mean                   2.165920e-01                    1.052155e+00
# std                    5.785090e-01                    2.539736e-01
# min                    0.000000e+00                    1.000000e+00
# 25%                    0.000000e+00                    1.000000e+00
# 50%                    0.000000e+00                    1.000000e+00
# 75%                    0.000000e+00                    1.000000e+00
# max                    1.200000e+01                    3.000000e+00
#
#        Delivery Method  Attendant at Birth  Payment Source  5 Minute APGAR  \
# count     2.897669e+06        2.897669e+06    2.897669e+06    2.897669e+06
# mean      1.783895e+00        1.346794e+00    1.853783e+00    8.814844e+00
# std       1.154466e+00        7.628875e-01    1.179579e+00    6.936444e-01
# min       1.000000e+00        1.000000e+00    1.000000e+00    0.000000e+00
# 25%       1.000000e+00        1.000000e+00    1.000000e+00    9.000000e+00
# 50%       1.000000e+00        1.000000e+00    2.000000e+00    9.000000e+00
# 75%       3.000000e+00        1.000000e+00    2.000000e+00    9.000000e+00
# max       4.000000e+00        9.000000e+00    9.000000e+00    1.000000e+01
#
#        10 Minute APGAR  Plurality (Number of Babies)  \
# count     2.897669e+06                  2.897669e+06
# mean      8.732565e+01                  1.026239e+00
# std       7.371883e+00                  1.643346e-01
# min       0.000000e+00                  1.000000e+00
# 25%       8.800000e+01                  1.000000e+00
# 50%       8.800000e+01                  1.000000e+00
# 75%       8.800000e+01                  1.000000e+00
# max       8.800000e+01                  5.000000e+00
#
#        Gestation Duration (wks)  Birth Weight (g)
# count              2.897669e+06      2.897669e+06
# mean               3.869167e+01      3.296630e+03
# std                2.188228e+00      5.437645e+02
# min                1.700000e+01      2.500000e+02
# 25%                3.800000e+01      2.995000e+03
# 50%                3.900000e+01      3.319000e+03
# 75%                4.000000e+01      3.640000e+03
# max                4.700000e+01      8.160000e+03
#
# [8 rows x 34 columns]

# %%
df.describe(include = object)
# Out:
#        Paternity Acknowledged      WIC Pre-pregnancy Diabetes  \
# count                 2897669  2897669                2897669
# unique                      3        2                      2
# top                         X        N                      N
# freq                  1920101  2023169                2869761
#
#        Gestational Diabetes Pre-pregnancy Hypertension  \
# count               2897669                    2897669
# unique                    2                          2
# top                       N                          N
# freq                2694129                    2832778
#
#        Gestational Hypertension Hypertension Eclampsia Previous Preterm Birth  \
# count                   2897669                2897669                2897669
# unique                        2                      2                      2
# top                           N                      N                      N
# freq                    2665672                2889022                2793947
#
#        Infertility treatment used Fertility Enhancing Drugs  ...  \
# count                     2897669                   2897669  ...
# unique                          2                         3  ...
# top                             N                         X  ...
# freq                      2844043                   2844043  ...
#
#        Gastroschisis Limb Reduction Defect Cleft lip Cleft Palate  \
# count        2897669               2897669   2897669      2897669
# unique             2                     2         2            2
# top                N                     N         N            N
# freq         2897096               2897301   2896245      2896933
#
#        Down Syndrome Suspected Chromosomal Disorder Hypospadias  \
# count        2897669                        2897669     2897669
# unique             3                              3           2
# top                N                              N           N
# freq         2896097                        2896469     2895869
#
#        Infant Transferred Infant Living Infant Breastfed
# count             2897669       2897669          2897669
# unique                  2             2                2
# top                     N             Y                Y
# freq              2868157       2896446          2459568
#
# [4 rows x 53 columns]

# %%
#https://datatofish.com/correlation-matrix-pandas/
corrMatrix = df[Numeric+Ordered_Categoricals].corr()
corrMatrix
# Out:
#                                       Maternal Age  Paternal Age  \
# Maternal Age                              1.000000      0.744431
# Paternal Age                              0.744431      1.000000
# Prior births, now living                  0.320368      0.263538
# Prior births, now dead                    0.023926      0.021422
# Prior terminations                        0.175999      0.137499
# Interval since last Live Birth (Mo)      -0.265251     -0.225184
# Number of Prenatal Visits                 0.075558      0.044474
# Daily Cigarette use before Pregnancy     -0.064078     -0.032446
# Daily Cigarette use, 1st Trimester       -0.045028     -0.015162
# Daily Cigarette use, 2nd Trimester       -0.035171     -0.006475
# Daily Cigarette use, 3rd Trimester       -0.030275     -0.003310
# BMI                                       0.031591      0.020595
# Weight Gain                              -0.031701     -0.029200
# Number of Previous Cesareans              0.152941      0.123861
# 5 Minute APGAR                            0.010706      0.009769
# 10 Minute APGAR                           0.004804      0.004034
# Plurality (Number of Babies)              0.047788      0.039294
# Gestation Duration (wks)                 -0.050870     -0.038515
# Birth Weight (g)                          0.043259      0.028663
# Maternal Education                        0.402273      0.278854
# Paternal Education                        0.324803      0.258931
# Month prenatal care Began                -0.021672     -0.010988
#
#                                       Prior births, now living  \
# Maternal Age                                          0.320368
# Paternal Age                                          0.263538
# Prior births, now living                              1.000000
# Prior births, now dead                                0.057896
# Prior terminations                                    0.180281
# Interval since last Live Birth (Mo)                  -0.689907
# Number of Prenatal Visits                            -0.097000
# Daily Cigarette use before Pregnancy                  0.036071
# Daily Cigarette use, 1st Trimester                    0.058090
# Daily Cigarette use, 2nd Trimester                    0.065845
# Daily Cigarette use, 3rd Trimester                    0.066344
# BMI                                                   0.085984
# Weight Gain                                          -0.109570
# Number of Previous Cesareans                          0.283507
# 5 Minute APGAR                                        0.029070
# 10 Minute APGAR                                       0.009427
# Plurality (Number of Babies)                          0.094520
# Gestation Duration (wks)                             -0.072984
# Birth Weight (g)                                      0.027379
# Maternal Education                                   -0.198561
# Paternal Education                                   -0.142263
# Month prenatal care Began                             0.024760
#
#                                       Prior births, now dead  \
# Maternal Age                                        0.023926
# Paternal Age                                        0.021422
# Prior births, now living                            0.057896
# Prior births, now dead                              1.000000
# Prior terminations                                  0.038970
# Interval since last Live Birth (Mo)                -0.059949
# Number of Prenatal Visits                          -0.003502
# Daily Cigarette use before Pregnancy                0.012479
# Daily Cigarette use, 1st Trimester                  0.014314
# Daily Cigarette use, 2nd Trimester                  0.014944
# Daily Cigarette use, 3rd Trimester                  0.013701
# BMI                                                 0.014025
# Weight Gain                                        -0.010902
# Number of Previous Cesareans                        0.038528
# 5 Minute APGAR                                     -0.004635
# 10 Minute APGAR                                    -0.001331
# Plurality (Number of Babies)                        0.005399
# Gestation Duration (wks)                           -0.019201
# Birth Weight (g)                                   -0.011783
# Maternal Education                                 -0.026043
# Paternal Education                                 -0.020078
# Month prenatal care Began                           0.003568
#
#                                       Prior terminations  \
# Maternal Age                                    0.175999
# Paternal Age                                    0.137499
# Prior births, now living                        0.180281
# Prior births, now dead                          0.038970
# Prior terminations                              1.000000
# Interval since last Live Birth (Mo)            -0.137912
# Number of Prenatal Visits                       0.032746
# Daily Cigarette use before Pregnancy            0.059667
# Daily Cigarette use, 1st Trimester              0.059483
# Daily Cigarette use, 2nd Trimester              0.056128
# Daily Cigarette use, 3rd Trimester              0.053456
# BMI                                             0.052080
# Weight Gain                                    -0.011339
# Number of Previous Cesareans                    0.080950
# 5 Minute APGAR                                 -0.005230
# 10 Minute APGAR                                -0.003021
# Plurality (Number of Babies)                    0.021202
# Gestation Duration (wks)                       -0.041441
# Birth Weight (g)                               -0.018994
# Maternal Education                             -0.017224
# Paternal Education                             -0.013236
# Month prenatal care Began                      -0.002496
#
#                                       Interval since last Live Birth (Mo)  \
# Maternal Age                                                    -0.265251
# Paternal Age                                                    -0.225184
# Prior births, now living                                        -0.689907
# Prior births, now dead                                          -0.059949
# Prior terminations                                              -0.137912
# Interval since last Live Birth (Mo)                              1.000000
# Number of Prenatal Visits                                        0.053424
# Daily Cigarette use before Pregnancy                            -0.019314
# Daily Cigarette use, 1st Trimester                              -0.039032
# Daily Cigarette use, 2nd Trimester                              -0.045748
# Daily Cigarette use, 3rd Trimester                              -0.046514
# BMI                                                             -0.070820
# Weight Gain                                                      0.114989
# Number of Previous Cesareans                                    -0.294009
# 5 Minute APGAR                                                  -0.049104
# 10 Minute APGAR                                                 -0.022183
# Plurality (Number of Babies)                                    -0.108189
# Gestation Duration (wks)                                         0.066914
# Birth Weight (g)                                                -0.057764
# Maternal Education                                               0.094294
# Paternal Education                                               0.064997
# Month prenatal care Began                                       -0.007523
#
#                                       Number of Prenatal Visits  \
# Maternal Age                                           0.075558
# Paternal Age                                           0.044474
# Prior births, now living                              -0.097000
# Prior births, now dead                                -0.003502
# Prior terminations                                     0.032746
# Interval since last Live Birth (Mo)                    0.053424
# Number of Prenatal Visits                              1.000000
# Daily Cigarette use before Pregnancy                  -0.022835
# Daily Cigarette use, 1st Trimester                    -0.036960
# Daily Cigarette use, 2nd Trimester                    -0.040410
# Daily Cigarette use, 3rd Trimester                    -0.038570
# BMI                                                    0.055868
# Weight Gain                                            0.059994
# Number of Previous Cesareans                          -0.019117
# 5 Minute APGAR                                         0.017624
# 10 Minute APGAR                                        0.011958
# Plurality (Number of Babies)                           0.020760
# Gestation Duration (wks)                               0.133990
# Birth Weight (g)                                       0.117615
# Maternal Education                                     0.141433
# Paternal Education                                     0.100752
# Month prenatal care Began                             -0.109605
#
#                                       Daily Cigarette use before Pregnancy  \
# Maternal Age                                                     -0.064078
# Paternal Age                                                     -0.032446
# Prior births, now living                                          0.036071
# Prior births, now dead                                            0.012479
# Prior terminations                                                0.059667
# Interval since last Live Birth (Mo)                              -0.019314
# Number of Prenatal Visits                                        -0.022835
# Daily Cigarette use before Pregnancy                              1.000000
# Daily Cigarette use, 1st Trimester                                0.790631
# Daily Cigarette use, 2nd Trimester                                0.693415
# Daily Cigarette use, 3rd Trimester                                0.639927
# BMI                                                               0.014905
# Weight Gain                                                       0.022954
# Number of Previous Cesareans                                      0.017011
# 5 Minute APGAR                                                   -0.016138
# 10 Minute APGAR                                                  -0.007448
# Plurality (Number of Babies)                                      0.000948
# Gestation Duration (wks)                                         -0.014246
# Birth Weight (g)                                                 -0.058761
# Maternal Education                                               -0.148062
# Paternal Education                                               -0.120122
# Month prenatal care Began                                         0.008608
#
#                                       Daily Cigarette use, 1st Trimester  \
# Maternal Age                                                   -0.045028
# Paternal Age                                                   -0.015162
# Prior births, now living                                        0.058090
# Prior births, now dead                                          0.014314
# Prior terminations                                              0.059483
# Interval since last Live Birth (Mo)                            -0.039032
# Number of Prenatal Visits                                      -0.036960
# Daily Cigarette use before Pregnancy                            0.790631
# Daily Cigarette use, 1st Trimester                              1.000000
# Daily Cigarette use, 2nd Trimester                              0.872830
# Daily Cigarette use, 3rd Trimester                              0.809953
# BMI                                                             0.010232
# Weight Gain                                                    -0.001561
# Number of Previous Cesareans                                    0.025085
# 5 Minute APGAR                                                 -0.013527
# 10 Minute APGAR                                                -0.005890
# Plurality (Number of Babies)                                    0.000634
# Gestation Duration (wks)                                       -0.019294
# Birth Weight (g)                                               -0.067573
# Maternal Education                                             -0.136774
# Paternal Education                                             -0.108744
# Month prenatal care Began                                       0.010294
#
#                                       Daily Cigarette use, 2nd Trimester  ...  \
# Maternal Age                                                   -0.035171  ...
# Paternal Age                                                   -0.006475  ...
# Prior births, now living                                        0.065845  ...
# Prior births, now dead                                          0.014944  ...
# Prior terminations                                              0.056128  ...
# Interval since last Live Birth (Mo)                            -0.045748  ...
# Number of Prenatal Visits                                      -0.040410  ...
# Daily Cigarette use before Pregnancy                            0.693415  ...
# Daily Cigarette use, 1st Trimester                              0.872830  ...
# Daily Cigarette use, 2nd Trimester                              1.000000  ...
# Daily Cigarette use, 3rd Trimester                              0.929206  ...
# BMI                                                             0.007820  ...
# Weight Gain                                                    -0.011895  ...
# Number of Previous Cesareans                                    0.027616  ...
# 5 Minute APGAR                                                 -0.011974  ...
# 10 Minute APGAR                                                -0.005036  ...
# Plurality (Number of Babies)                                    0.001451  ...
# Gestation Duration (wks)                                       -0.020916  ...
# Birth Weight (g)                                               -0.068496  ...
# Maternal Education                                             -0.127601  ...
# Paternal Education                                             -0.100144  ...
# Month prenatal care Began                                       0.009787  ...
#
#                                       Weight Gain  \
# Maternal Age                            -0.031701
# Paternal Age                            -0.029200
# Prior births, now living                -0.109570
# Prior births, now dead                  -0.010902
# Prior terminations                      -0.011339
# Interval since last Live Birth (Mo)      0.114989
# Number of Prenatal Visits                0.059994
# Daily Cigarette use before Pregnancy     0.022954
# Daily Cigarette use, 1st Trimester      -0.001561
# Daily Cigarette use, 2nd Trimester      -0.011895
# Daily Cigarette use, 3rd Trimester      -0.014705
# BMI                                     -0.267230
# Weight Gain                              1.000000
# Number of Previous Cesareans            -0.035989
# 5 Minute APGAR                          -0.000806
# 10 Minute APGAR                          0.003798
# Plurality (Number of Babies)             0.065375
# Gestation Duration (wks)                 0.062195
# Birth Weight (g)                         0.161227
# Maternal Education                       0.076530
# Paternal Education                       0.066905
# Month prenatal care Began               -0.011882
#
#                                       Number of Previous Cesareans  \
# Maternal Age                                              0.152941
# Paternal Age                                              0.123861
# Prior births, now living                                  0.283507
# Prior births, now dead                                    0.038528
# Prior terminations                                        0.080950
# Interval since last Live Birth (Mo)                      -0.294009
# Number of Prenatal Visits                                -0.019117
# Daily Cigarette use before Pregnancy                      0.017011
# Daily Cigarette use, 1st Trimester                        0.025085
# Daily Cigarette use, 2nd Trimester                        0.027616
# Daily Cigarette use, 3rd Trimester                        0.027227
# BMI                                                       0.121699
# Weight Gain                                              -0.035989
# Number of Previous Cesareans                              1.000000
# 5 Minute APGAR                                           -0.012908
# 10 Minute APGAR                                          -0.002314
# Plurality (Number of Babies)                              0.024910
# Gestation Duration (wks)                                 -0.069765
# Birth Weight (g)                                          0.006039
# Maternal Education                                       -0.041766
# Paternal Education                                       -0.035960
# Month prenatal care Began                                 0.003204
#
#                                       5 Minute APGAR  10 Minute APGAR  \
# Maternal Age                                0.010706         0.004804
# Paternal Age                                0.009769         0.004034
# Prior births, now living                    0.029070         0.009427
# Prior births, now dead                     -0.004635        -0.001331
# Prior terminations                         -0.005230        -0.003021
# Interval since last Live Birth (Mo)        -0.049104        -0.022183
# Number of Prenatal Visits                   0.017624         0.011958
# Daily Cigarette use before Pregnancy       -0.016138        -0.007448
# Daily Cigarette use, 1st Trimester         -0.013527        -0.005890
# Daily Cigarette use, 2nd Trimester         -0.011974        -0.005036
# Daily Cigarette use, 3rd Trimester         -0.011208        -0.004674
# BMI                                        -0.046943        -0.018931
# Weight Gain                                -0.000806         0.003798
# Number of Previous Cesareans               -0.012908        -0.002314
# 5 Minute APGAR                              1.000000         0.678119
# 10 Minute APGAR                             0.678119         1.000000
# Plurality (Number of Babies)               -0.055598        -0.018205
# Gestation Duration (wks)                    0.133498         0.066341
# Birth Weight (g)                            0.114497         0.062097
# Maternal Education                          0.012622         0.009222
# Paternal Education                          0.011964         0.007990
# Month prenatal care Began                  -0.000768        -0.001163
#
#                                       Plurality (Number of Babies)  \
# Maternal Age                                              0.047788
# Paternal Age                                              0.039294
# Prior births, now living                                  0.094520
# Prior births, now dead                                    0.005399
# Prior terminations                                        0.021202
# Interval since last Live Birth (Mo)                      -0.108189
# Number of Prenatal Visits                                 0.020760
# Daily Cigarette use before Pregnancy                      0.000948
# Daily Cigarette use, 1st Trimester                        0.000634
# Daily Cigarette use, 2nd Trimester                        0.001451
# Daily Cigarette use, 3rd Trimester                        0.000841
# BMI                                                       0.025665
# Weight Gain                                               0.065375
# Number of Previous Cesareans                              0.024910
# 5 Minute APGAR                                           -0.055598
# 10 Minute APGAR                                          -0.018205
# Plurality (Number of Babies)                              1.000000
# Gestation Duration (wks)                                 -0.222616
# Birth Weight (g)                                         -0.261505
# Maternal Education                                        0.017471
# Paternal Education                                        0.014719
# Month prenatal care Began                                -0.001451
#
#                                       Gestation Duration (wks)  \
# Maternal Age                                         -0.050870
# Paternal Age                                         -0.038515
# Prior births, now living                             -0.072984
# Prior births, now dead                               -0.019201
# Prior terminations                                   -0.041441
# Interval since last Live Birth (Mo)                   0.066914
# Number of Prenatal Visits                             0.133990
# Daily Cigarette use before Pregnancy                 -0.014246
# Daily Cigarette use, 1st Trimester                   -0.019294
# Daily Cigarette use, 2nd Trimester                   -0.020916
# Daily Cigarette use, 3rd Trimester                   -0.019723
# BMI                                                  -0.042222
# Weight Gain                                           0.062195
# Number of Previous Cesareans                         -0.069765
# 5 Minute APGAR                                        0.133498
# 10 Minute APGAR                                       0.066341
# Plurality (Number of Babies)                         -0.222616
# Gestation Duration (wks)                              1.000000
# Birth Weight (g)                                      0.452748
# Maternal Education                                    0.034625
# Paternal Education                                    0.033402
# Month prenatal care Began                            -0.009929
#
#                                       Birth Weight (g)  Maternal Education  \
# Maternal Age                                  0.043259            0.402273
# Paternal Age                                  0.028663            0.278854
# Prior births, now living                      0.027379           -0.198561
# Prior births, now dead                       -0.011783           -0.026043
# Prior terminations                           -0.018994           -0.017224
# Interval since last Live Birth (Mo)          -0.057764            0.094294
# Number of Prenatal Visits                     0.117615            0.141433
# Daily Cigarette use before Pregnancy         -0.058761           -0.148062
# Daily Cigarette use, 1st Trimester           -0.067573           -0.136774
# Daily Cigarette use, 2nd Trimester           -0.068496           -0.127601
# Daily Cigarette use, 3rd Trimester           -0.065556           -0.121319
# BMI                                           0.066847           -0.117764
# Weight Gain                                   0.161227            0.076530
# Number of Previous Cesareans                  0.006039           -0.041766
# 5 Minute APGAR                                0.114497            0.012622
# 10 Minute APGAR                               0.062097            0.009222
# Plurality (Number of Babies)                 -0.261505            0.017471
# Gestation Duration (wks)                      0.452748            0.034625
# Birth Weight (g)                              1.000000            0.072975
# Maternal Education                            0.072975            1.000000
# Paternal Education                            0.057405            0.646873
# Month prenatal care Began                    -0.009596           -0.048212
#
#                                       Paternal Education  \
# Maternal Age                                    0.324803
# Paternal Age                                    0.258931
# Prior births, now living                       -0.142263
# Prior births, now dead                         -0.020078
# Prior terminations                             -0.013236
# Interval since last Live Birth (Mo)             0.064997
# Number of Prenatal Visits                       0.100752
# Daily Cigarette use before Pregnancy           -0.120122
# Daily Cigarette use, 1st Trimester             -0.108744
# Daily Cigarette use, 2nd Trimester             -0.100144
# Daily Cigarette use, 3rd Trimester             -0.094746
# BMI                                            -0.163320
# Weight Gain                                     0.066905
# Number of Previous Cesareans                   -0.035960
# 5 Minute APGAR                                  0.011964
# 10 Minute APGAR                                 0.007990
# Plurality (Number of Babies)                    0.014719
# Gestation Duration (wks)                        0.033402
# Birth Weight (g)                                0.057405
# Maternal Education                              0.646873
# Paternal Education                              1.000000
# Month prenatal care Began                      -0.034754
#
#                                       Month prenatal care Began
# Maternal Age                                          -0.021672
# Paternal Age                                          -0.010988
# Prior births, now living                               0.024760
# Prior births, now dead                                 0.003568
# Prior terminations                                    -0.002496
# Interval since last Live Birth (Mo)                   -0.007523
# Number of Prenatal Visits                             -0.109605
# Daily Cigarette use before Pregnancy                   0.008608
# Daily Cigarette use, 1st Trimester                     0.010294
# Daily Cigarette use, 2nd Trimester                     0.009787
# Daily Cigarette use, 3rd Trimester                     0.009040
# BMI                                                   -0.003819
# Weight Gain                                           -0.011882
# Number of Previous Cesareans                           0.003204
# 5 Minute APGAR                                        -0.000768
# 10 Minute APGAR                                       -0.001163
# Plurality (Number of Babies)                          -0.001451
# Gestation Duration (wks)                              -0.009929
# Birth Weight (g)                                      -0.009596
# Maternal Education                                    -0.048212
# Paternal Education                                    -0.034754
# Month prenatal care Began                              1.000000
#
# [22 rows x 22 columns]

# %%
sns.set(rc={'figure.figsize':(30,30)})
sns.heatmap(corrMatrix, annot=True)
plt.show()

# %% [markdown]
# Based on the correlations identified in this matrix and later testing, I determined that I would drop several variables:  'Daily Cigarette use before Pregnancy','Daily Cigarette use, 1st Trimester',
#             'Daily Cigarette use, 2nd Trimester','10 Minute APGAR'

# %%
dropVars = ['Daily Cigarette use before Pregnancy','Daily Cigarette use, 1st Trimester',
            'Daily Cigarette use, 2nd Trimester','10 Minute APGAR']

df.drop(dropVars, axis =1, inplace = True)

# %%
#reset groups without dropped variables
Binary_Categoricals = ['Maternal Nativity','Paternity Acknowledged', 'WIC','Pre-pregnancy Diabetes', 
                      'Gestational Diabetes', 'Pre-pregnancy Hypertension', 'Gestational Hypertension',
                      'Hypertension Eclampsia', 'Previous Preterm Birth','Infertility treatment used', 'Fertility Enhancing Drugs', 
                      'Asst. Reproductive Tech', 'Gonorrhea', 'Syphilis', 'Chlamydia', 'Hep B', 'Hep C',
                      'Successful External Cephalic Version', 'Failed Cephalic Version','Induced Labor', 'Augmented Labor', 
                      'Steroids', 'Antibiotics', 'Chorioamnionitis', 'Anesthesia','If Cesarean, Labor Attempted',
                      'Maternal Transfusion', 'Perineal Laceration', 'Ruptured Uterus', 'Unplanned Hysterectomy',
                      'Maternal admit to ICU', 'Mother Transferred','infant sex','Assisted Ventilation immediately',
                      'Assisted ventilation >6hr', 'Admission to NICU', 'Surffactant', 'Antibiotis for Newborn', 'Seizures',
                      'Anencephaly', 'Spina Bifida', 'Cyanotic Congenital Heart Disease', 'Congenital Diaphragmatic Hernia',
                      'Omphalocele', 'Gastroschisis', 'Limb Reduction Defect', 'Cleft lip', 'Cleft Palate',  'Hypospadias', 'Infant Transferred', 'Infant Living', 'Infant Breastfed']
Ordered_Categoricals = ['Maternal Education','Paternal Education','Month prenatal care Began']
Unordered_Categoricals = ['Birth Place','Marital Status','Maternal Residence Status','Maternal Race','Maternal Hispanic Origin', 
                         'Paternal Race', 'Paternal Hispanic Origin', 'Fetal Presentation at Delivery','Delivery Method',
                         'Attendant at Birth','Payment Source','Down Syndrome', 'Suspected Chromosomal Disorder']
Numeric = ['Maternal Age','Paternal Age','Prior births, now living', 'Prior births, now dead', 'Prior terminations',
          'Interval since last Live Birth (Mo)', 'Number of Prenatal Visits', 'Daily Cigarette use, 3rd Trimester',
          'BMI', 'Weight Gain', 'Number of Previous Cesareans','5 Minute APGAR', 'Plurality (Number of Babies)',
          'Gestation Duration (wks)', 'Birth Weight (g)']

# %% [markdown]
# ## Feature Engineering
# - Encoding
# - Scaling
#
# Due to processing limitations, I tested methods using a subset of the dataframe first and in this notebook. A second notebook is uploaded run on the full dataset, however, this took an long time to complete.

# %%
df1 = df.sample(frac = 
               .01)
df1.reset_index(drop=True, inplace =True)
df1 = df1[Numeric+Ordered_Categoricals]

# %%
#In the first iteration of testing, I encoded the ordered and binary categorical data at this stage. However, I later
#decided not to use the binary data in the model (explained below) and have therfore left that out here. The entire 
#process can be found in the Exploratory Analysis Notebook
le = LabelEncoder()

for i in (Ordered_Categoricals):
    df1 = df1.assign(i=le.fit_transform(df1[i]))
df1.shape
# Out:
# (28977, 19)

# %%
#Scale the data so that all features have equal weight in the model
scaler = MinMaxScaler()
scaler.fit(df1)
df_scaled = scaler.transform(df1)

# %% [markdown]
# ## Modeling
# I Started with a KMeans to see if the data have any obvious clusters, but based upon my research, the best algoithm for clustering this data will be the DBSCAN (Density-Based Spatial Clustering of Applications with Noise). DBSCAN uses a threshold epsilon to indicate the neighbors that are considered part of the cluster. DBSCAN corepoints (the center of the cluster) is determined by the least min_sample points (min_sample being the minimum number of neighbors required to be considered a corepoint).
#
# The reasons DBSCAN is suited to this data:
# 1. The nature of the data I am using is very large, and the DBSCAN model is capable of handling large datasets efficiently
# 2. DBSCAN handles noise, and this dataset contains a lot of noise and overlapping groups
# 3. DBSCAN is able to handle oddly shaped clusters, while other methods, like KMeans, are limited to circular clusters.
#
# Drawbacks of the DBSCAN model are that if the clusters have differing densities, they are not detected well.

# %%
#First I will look for clusters using kmeans
model = KMeans()

visualizer = KElbowVisualizer(model, k=(2,50), metric = 'calinski_harabasz', timings=False)
#the Calinski harabasz metric is good for identifying optimal number of clusters when this is unknown
visualizer.fit(df_scaled)        # Fit the data to the visualizer
visualizer.show()
# Out:
# C:\Users\15856\anaconda3\lib\site-packages\yellowbrick\utils\kneed.py:182: YellowbrickWarning: No "knee" or "elbow point" detected This could be due to bad clustering, no actual clusters being formed etc.
#   warnings.warn(warning_message, YellowbrickWarning)
# C:\Users\15856\anaconda3\lib\site-packages\yellowbrick\utils\kneed.py:140: YellowbrickWarning: No 'knee' or 'elbow point' detected This could be due to bad clustering, no actual clusters being formed etc.
#   warnings.warn(warning_message, YellowbrickWarning)
# C:\Users\15856\anaconda3\lib\site-packages\yellowbrick\cluster\elbow.py:343: YellowbrickWarning: No 'knee' or 'elbow' point detected, pass `locate_elbow=False` to remove the warning
#   warnings.warn(warning_message, YellowbrickWarning)

# %% [raw]
# As I expected, no obvious clusters where identified in the data using the KMeans method. I will proceed to see if I can identify clusters using DBSCAN. To begin, I need to identify the ideal epsilon parameter value.

# %%
neigh = NearestNeighbors(n_neighbors=2)
nbrs = neigh.fit(df_scaled)
distances, indices = nbrs.kneighbors(df_scaled)
distances = np.sort(distances, axis=0)
distances = distances[:,1]
plt.plot(distances)

# %%
m = DBSCAN(eps=.3, min_samples=18*2, n_jobs=-1) #Eps is based on the graph above, min_samples is base on the rule of thumb minPts = 2·dim
m.fit(df_scaled)
core_samples_mask = np.zeros_like(m.labels_, dtype=bool)
core_samples_mask[m.core_sample_indices_] = True
labels = m.labels_

# Number of clusters in labels, ignoring noise if present.
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
n_noise_ = list(labels).count(-1)

print('Estimated number of clusters: %d' % n_clusters_)
print('Estimated number of noise points: %d' % n_noise_)
print("Silhouette Coefficient: %0.3f"
      % metrics.silhouette_score(df_scaled, labels))
# Out:
# Estimated number of clusters: 3
# Estimated number of noise points: 2915
# Silhouette Coefficient: 0.210

# %%
colors = ['royalblue', 'maroon', 'forestgreen', 'mediumorchid', 'tan', 'deeppink', 'olive', 'goldenrod', 'lightcyan', 'navy']
vectorizer = np.vectorize(lambda x: colors[x % len(colors)])

# %%
clusters = m.labels_
plt.scatter(df_scaled[:,0], df_scaled[:,1], c=vectorizer(clusters))

# %% [markdown]
# Next I used PCA to identify the variables responsible for the majority of the variance in order to reduce the dimensionality of the dataset. I then proceeded with the DBSPAN clustering algorithm.

# %%
pca = PCA(n_components=.95)
principal_components = pca.fit_transform(df_scaled)
len(pca.components_)
# Out:
# 10

# %%
principal_df = pd.DataFrame(data = principal_components)
print(principal_df.shape)
# Out:
# (28977, 10)

# %%
neigh = NearestNeighbors(n_neighbors=2)
nbrs = neigh.fit(principal_df)
distances, indices = nbrs.kneighbors(principal_df)

# %%
distances = np.sort(distances, axis=0)
distances = distances[:,1]
plt.plot(distances)

# %%
m = DBSCAN(eps=.25, min_samples=20, n_jobs=-1) #based on the elbow in the plot, eps is set at .25
m.fit(principal_df)
# Out:
# DBSCAN(eps=0.25, min_samples=20, n_jobs=-1)

# %%
core_samples_mask = np.zeros_like(m.labels_, dtype=bool)
core_samples_mask[m.core_sample_indices_] = True
labels = m.labels_

# Number of clusters in labels, ignoring noise if present.
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
n_noise_ = list(labels).count(-1)

print('Estimated number of clusters: %d' % n_clusters_)
print('Estimated number of noise points: %d' % n_noise_)
print("Silhouette Coefficient: %0.3f"
      % metrics.silhouette_score(principal_df, labels)) #https://medium.com/@shritam/how-dbscan-algorithm-works-2b5bef80fb3
# Out:
# Estimated number of clusters: 3
# Estimated number of noise points: 1897
# Silhouette Coefficient: 0.289

# %% [markdown]
# The silhouette coeeficient improved with PCA feature selection and the number of clusters remained the same.

# %%
clusters = m.labels_

# %%
plt.scatter(principal_df.iloc[:,0], principal_df.iloc[:,1], c=vectorizer(clusters))

# %%
#Finally, I want to identify some of the characteristics of my clusters:
clusters = m.fit_predict(principal_df)
df1['cluster'] = clusters

# %%
clusters_grouped = df1.groupby(by = ['cluster']).median()
#I am only interested in when the clusters are different, so I will drop columns where all the data is the same
clusters_grouped.drop(clusters_grouped.std()[(clusters_grouped.std() == 0)].index, axis=1)
# Out:
#          Maternal Age  Paternal Age  Prior births, now living  \
# cluster
# -1                 31            34                         1
#  0                 30            32                         1
#  1                 27            29                         0
#  2                 20            23                         0
#
#          Interval since last Live Birth (Mo)  Number of Prenatal Visits   BMI  \
# cluster
# -1                                        74                         10  29.7
#  0                                        36                         12  26.1
#  1                                       888                         12  25.1
#  2                                       888                         12  25.0
#
#          Weight Gain  Gestation Duration (wks)  Birth Weight (g)  \
# cluster
# -1                27                        38              3080
#  0                28                        39              3350
#  1                31                        39              3294
#  2                30                        39              3195
#
#          Maternal Education  Paternal Education
# cluster
# -1                        4                   4
#  0                        4                   4
#  1                        5                   4
#  2                        3                   9

# %% [markdown]
# In the above table, the noisy data is given the -1 cluster value while the 4 clusters are shown iwht 0-3.

# %%
pd.set_option('display.max_rows', df1.shape[0]+1)

# %%
clusters_grouped = df1.groupby(by = ['cluster']).mean()
#I am only interested in when the clusters are different, so I will drop columns where all the data is the same
clusters_grouped.drop(clusters_grouped.std()[(clusters_grouped.std() == 0)].index, axis=1).T
# Out:
# cluster                                       -1            0            1  \
# Maternal Age                           31.537164    30.196101    27.023533
# Paternal Age                           34.297312    32.523078    29.357244
# Prior births, now living                1.670532     1.745293     0.000000
# Prior births, now dead                  0.031629     0.019009     0.000000
# Prior terminations                      0.633105     0.522045     0.264720
# Interval since last Live Birth (Mo)   309.186610    47.714138   888.000000
# Number of Prenatal Visits               9.715867    11.489251    11.927417
# Daily Cigarette use, 3rd Trimester      0.577754     0.428337     0.215953
# BMI                                    31.703163    27.345876    26.528674
# Weight Gain                            32.134950    28.488218    31.944996
# Number of Previous Cesareans            0.699526     0.295154     0.000567
# 5 Minute APGAR                          7.883500     8.901373     8.830451
# Plurality (Number of Babies)            1.110701     1.031519     1.003686
# Gestation Duration (wks)               36.736426    38.720211    38.978074
# Birth Weight (g)                     2956.065894  3344.464594  3281.863718
# Maternal Education                      4.060095     4.406292     4.741423
# Paternal Education                      4.470216     4.191668     4.409319
# Month prenatal care Began               7.412757     2.851937     2.786788
# i                                       4.119135     2.851937     2.786788
#
# cluster                                        2
# Maternal Age                           20.939394
# Paternal Age                           24.212121
# Prior births, now living                0.000000
# Prior births, now dead                  0.000000
# Prior terminations                      0.393939
# Interval since last Live Birth (Mo)   888.000000
# Number of Prenatal Visits              11.939394
# Daily Cigarette use, 3rd Trimester      0.757576
# BMI                                    25.187879
# Weight Gain                            30.303030
# Number of Previous Cesareans            0.000000
# 5 Minute APGAR                          8.878788
# Plurality (Number of Babies)            1.030303
# Gestation Duration (wks)               38.666667
# Birth Weight (g)                     3106.515152
# Maternal Education                      2.909091
# Paternal Education                      9.000000
# Month prenatal care Began               2.848485
# i                                       2.848485

# %% [markdown]
# ## Conclusions:
# After dimensionality reduction, there appear to be 3 clusters in the data. Upon closer analysis of the differences between those clusters, I found that parental age, prior births, birth weight, maternal BMI,and parental education were among the features that most varied among groups. These data can be used to now target those populations most at risk of a negative outcome, for example, the cluster with the highest parental ages also had higher APGAR5 scores, indicating poorer health indicators for the infant after birth.
#
# Additional analysis may be required to tease out the nuances of the groups and discover additional targets for intervension.
#
# Using this project I was able to gain experience applying a clustering algorithm as well as working with a larger, more complex dataset than I am used to. I was able to gain a better understanding of PCA and how to apply it practically, as well as what DBSCAN is, when it is best applied, and how to determine the values for each of the parameters. I feel that I have gained a lot through this project in terms of experience and practice.

# %%
end_time = time.time()

print('Runtime: '+ str((end_time - start_time)/60) + ' minutes')
# Out:
# Runtime: 6.521943159898123 minutes
