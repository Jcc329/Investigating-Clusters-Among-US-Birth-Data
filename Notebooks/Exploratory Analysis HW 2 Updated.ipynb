# %% [markdown]
# # Data 602 Homework 2 Exploratory Analysis
#
# The objective of this notebook is to perform exploratory analysis on the CDC natality data in order to create a clustering model that can be used to answer my guiding research questions:
#
# 1. Using U.S,. Natality data, specifically health metrics and pregnancy outcomes, can we identify hidden groups based on demographic characteristics that would benefit from additional care or consideration during the prenatal period?
# 2. By examining parental demographics and health metrics, are there hiden groups that have better or poorer natality outcomes? Which indicators best determine these outcomes.
#
# Using CDC natality data from 2019, I hope to answer these questions.
#
# Plan of action:
# - For each of object feature, I will use encoding to conver the feature into numeric format, more appropriate for machine learning models.
# - I will visualize the correlation matrix for the data to explore any related attributes.
# - I will apply any necessary transformations to the data and engage in feature scaling to prepare the data fo modeling.
# - Some of the feature engineering and selection was performed during cleaning, when the irrelevant features where dropped. I will perform additional feature engineering .
# - I will focus on DBSCAN clustering based on my research into which algorithm is best suited to large complext data. I will also test a Kmeans initially to see if any cluster's can be identified.
# - I will perform dimensionality reduction using PCA and visualize the clusters

# %%
import pandas as pd
from pandas.plotting import scatter_matrix
import numpy as np
import matplotlib.pyplot as plt # for visualizations
import seaborn as sns #for visualizations
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder #encoder for binary and ordered categorical data
from sklearn.preprocessing import OneHotEncoder #encoder for unordered categorical data
from sklearn.compose import ColumnTransformer 
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import time
start_time = time.time()

# %%
df1 = pd.read_csv('./NatalityData_cleaned_1.zip', compression = 'zip', low_memory = False)
df2 = pd.read_csv('./NatalityData_cleaned_2.zip', compression = 'zip', low_memory = False)
df3 = pd.read_csv('./NatalityData_cleaned_3.zip', compression = 'zip', low_memory = False)
df4 = pd.read_csv('./NatalityData_cleaned_4.zip', compression = 'zip', low_memory = False)


df= df1.append(df2)
df= df.append(df3)
df= df.append(df4)
df
# Out:
#         Unnamed: 0  Birth Place  Maternal Age  Maternal Nativity  \
# 0                1            1            40                  2
# 1                2            1            30                  1
# 2                3            1            25                  1
# 3                5            1            30                  1
# 4                6            1            33                  1
# ...            ...          ...           ...                ...
# 391003     3757576            1            22                  2
# 391004     3757577            1            25                  1
# 391005     3757578            1            35                  1
# 391006     3757579            1            38                  2
# 391007     3757580            1            23                  2
#
#         Maternal Residence Status  Maternal Race  Maternal Hispanic Origin  \
# 0                               1             10                         0
# 1                               1              3                         0
# 2                               1              1                         0
# 3                               1              6                         0
# 4                               2              1                         0
# ...                           ...            ...                       ...
# 391003                          1              1                         1
# 391004                          1             15                         2
# 391005                          2              1                         9
# 391006                          1              5                         0
# 391007                          1              5                         0
#
#        Paternity Acknowledged  Marital Status  Maternal Education  ...  \
# 0                           X             1.0                   7  ...
# 1                           X             1.0                   5  ...
# 2                           X             1.0                   6  ...
# 3                           Y             2.0                   6  ...
# 4                           X             1.0                   6  ...
# ...                       ...             ...                 ...  ...
# 391003                      Y             2.0                   3  ...
# 391004                      Y             2.0                   4  ...
# 391005                      X             1.0                   6  ...
# 391006                      X             1.0                   3  ...
# 391007                      X             1.0                   6  ...
#
#         Gastroschisis  Limb Reduction Defect  Cleft lip  Cleft Palate  \
# 0                   N                      N          N             N
# 1                   N                      N          N             N
# 2                   N                      N          N             N
# 3                   N                      N          N             N
# 4                   N                      N          N             N
# ...               ...                    ...        ...           ...
# 391003              N                      N          N             N
# 391004              N                      N          N             N
# 391005              N                      N          N             N
# 391006              N                      N          N             N
# 391007              N                      N          N             N
#
#         Down Syndrome  Suspected Chromosomal Disorder  Hypospadias  \
# 0                   N                               N            N
# 1                   N                               N            N
# 2                   N                               N            N
# 3                   N                               N            N
# 4                   N                               N            N
# ...               ...                             ...          ...
# 391003              N                               N            N
# 391004              N                               N            N
# 391005              N                               N            N
# 391006              N                               N            N
# 391007              N                               N            N
#
#         Infant Transferred  Infant Living  Infant Breastfed
# 0                        N              Y                 Y
# 1                        N              Y                 Y
# 2                        N              Y                 Y
# 3                        N              Y                 Y
# 4                        N              Y                 Y
# ...                    ...            ...               ...
# 391003                   N              Y                 Y
# 391004                   Y              Y                 Y
# 391005                   N              Y                 Y
# 391006                   N              Y                 Y
# 391007                   N              Y                 Y
#
# [2564260 rows x 88 columns]

# %%
df.drop(['Unnamed: 0'], axis = 1, inplace = True)

# %%
Binary_Categoricals = ['Maternal Nativity','Paternity Acknowledged', 'WIC','Pre-pregnancy Diabetes', 
                      'Gestational Diabetes', 'Pre-pregnancy Hypertension', 'Gestational Hypertension',
                      'Hypertension Eclampsia', 'Previous Preterm Birth','Infertility treatment used', 'Fertility Enhancing Drugs', 
                      'Asst. Reproductive Tech', 'Gonorrhea', 'Syphilis', 'Chlamydia', 'Hep B', 'Hep C',
                      'Successful External Cephalic Version', 'Failed Cephalic Version','Induced Labor', 'Augmented Labor', 
                      'Steroids', 'Antibiotics', 'Chorioamnionitis', 'Anesthesia','If Cesarean, Labor Attempted',
                      'Maternal Transfusion', 'Perineal Laceration', 'Ruptured Uterus', 'Unplanned Hysterectomy',
                      'Maternal admit to ICU', 'Mother Transferred','infant sex','Assisted Ventilation immediately',
                      'Assisted ventilation >6hr', 'Admission to NICU', 'Surffactant', 'Antibiotis for Newborn', 'Seizures',
                      'Anencephaly', 'Spina Bifida', 'Cyanotic Congenital Heart Disease', 'Congenital Diaphragmatic Hernia',
                      'Omphalocele', 'Gastroschisis', 'Limb Reduction Defect', 'Cleft lip', 'Cleft Palate',  'Hypospadias', 'Infant Transferred', 'Infant Living', 'Infant Breastfed']
Ordered_Categoricals = ['Maternal Education','Paternal Education','Month prenatal care Began']
Unordered_Categoricals = ['Birth Place','Marital Status','Maternal Residence Status','Maternal Race','Maternal Hispanic Origin', 
                         'Paternal Race', 'Paternal Hispanic Origin', 'Fetal Presentation at Delivery','Delivery Method',
                         'Attendant at Birth','Payment Source','Down Syndrome', 'Suspected Chromosomal Disorder']
Numeric = ['Maternal Age','Paternal Age','Prior births, now living', 'Prior births, now dead', 'Prior terminations',
          'Interval since last Live Birth (Mo)', 'Number of Prenatal Visits','Daily Cigarette use before Pregnancy', 
           'Daily Cigarette use, 1st Trimester','Daily Cigarette use, 2nd Trimester', 'Daily Cigarette use, 3rd Trimester',
          'BMI', 'Weight Gain', 'Number of Previous Cesareans','5 Minute APGAR', '10 Minute APGAR', 'Plurality (Number of Babies)',
          'Gestation Duration (wks)', 'Birth Weight (g)']

# %%
df.shape
# Out:
# (2564260, 87)

# %%
#https://datatofish.com/correlation-matrix-pandas/
corrMatrix = df[Numeric+Ordered_Categoricals].corr()
corrMatrix
# Out:
#                                       Maternal Age  Paternal Age  \
# Maternal Age                              1.000000      0.742961
# Paternal Age                              0.742961      1.000000
# Prior births, now living                  0.317024      0.260148
# Prior births, now dead                    0.023642      0.021472
# Prior terminations                        0.176324      0.136828
# Interval since last Live Birth (Mo)      -0.260955     -0.221550
# Number of Prenatal Visits                 0.076356      0.044453
# Daily Cigarette use before Pregnancy     -0.064467     -0.034659
# Daily Cigarette use, 1st Trimester       -0.046485     -0.018142
# Daily Cigarette use, 2nd Trimester       -0.037085     -0.010087
# Daily Cigarette use, 3rd Trimester       -0.032302     -0.006907
# BMI                                       0.026257      0.015999
# Weight Gain                              -0.032181     -0.030735
# Number of Previous Cesareans              0.152332      0.123680
# 5 Minute APGAR                            0.011400      0.011006
# 10 Minute APGAR                           0.004774      0.004186
# Plurality (Number of Babies)              0.046313      0.038391
# Gestation Duration (wks)                 -0.051283     -0.038865
# Birth Weight (g)                          0.041514      0.026678
# Maternal Education                        0.398882      0.274357
# Paternal Education                        0.316331      0.250323
# Month prenatal care Began                -0.019011     -0.008936
#
#                                       Prior births, now living  \
# Maternal Age                                          0.317024
# Paternal Age                                          0.260148
# Prior births, now living                              1.000000
# Prior births, now dead                                0.058212
# Prior terminations                                    0.180675
# Interval since last Live Birth (Mo)                  -0.688360
# Number of Prenatal Visits                            -0.095072
# Daily Cigarette use before Pregnancy                  0.036369
# Daily Cigarette use, 1st Trimester                    0.057252
# Daily Cigarette use, 2nd Trimester                    0.064825
# Daily Cigarette use, 3rd Trimester                    0.065407
# BMI                                                   0.087272
# Weight Gain                                          -0.109317
# Number of Previous Cesareans                          0.281444
# 5 Minute APGAR                                        0.027913
# 10 Minute APGAR                                       0.009045
# Plurality (Number of Babies)                          0.092996
# Gestation Duration (wks)                             -0.072662
# Birth Weight (g)                                      0.029535
# Maternal Education                                   -0.197251
# Paternal Education                                   -0.136074
# Month prenatal care Began                             0.020914
#
#                                       Prior births, now dead  \
# Maternal Age                                        0.023642
# Paternal Age                                        0.021472
# Prior births, now living                            0.058212
# Prior births, now dead                              1.000000
# Prior terminations                                  0.040174
# Interval since last Live Birth (Mo)                -0.060947
# Number of Prenatal Visits                          -0.002496
# Daily Cigarette use before Pregnancy                0.012838
# Daily Cigarette use, 1st Trimester                  0.014621
# Daily Cigarette use, 2nd Trimester                  0.014799
# Daily Cigarette use, 3rd Trimester                  0.013802
# BMI                                                 0.016411
# Weight Gain                                        -0.011331
# Number of Previous Cesareans                        0.039829
# 5 Minute APGAR                                     -0.004518
# 10 Minute APGAR                                    -0.001670
# Plurality (Number of Babies)                        0.005173
# Gestation Duration (wks)                           -0.019735
# Birth Weight (g)                                   -0.011635
# Maternal Education                                 -0.026450
# Paternal Education                                 -0.019930
# Month prenatal care Began                           0.003921
#
#                                       Prior terminations  \
# Maternal Age                                    0.176324
# Paternal Age                                    0.136828
# Prior births, now living                        0.180675
# Prior births, now dead                          0.040174
# Prior terminations                              1.000000
# Interval since last Live Birth (Mo)            -0.138263
# Number of Prenatal Visits                       0.029044
# Daily Cigarette use before Pregnancy            0.056671
# Daily Cigarette use, 1st Trimester              0.056842
# Daily Cigarette use, 2nd Trimester              0.053925
# Daily Cigarette use, 3rd Trimester              0.051295
# BMI                                             0.052320
# Weight Gain                                    -0.010774
# Number of Previous Cesareans                    0.081219
# 5 Minute APGAR                                 -0.004989
# 10 Minute APGAR                                -0.002684
# Plurality (Number of Babies)                    0.020863
# Gestation Duration (wks)                       -0.043521
# Birth Weight (g)                               -0.019077
# Maternal Education                             -0.019344
# Paternal Education                             -0.014944
# Month prenatal care Began                      -0.002778
#
#                                       Interval since last Live Birth (Mo)  \
# Maternal Age                                                    -0.260955
# Paternal Age                                                    -0.221550
# Prior births, now living                                        -0.688360
# Prior births, now dead                                          -0.060947
# Prior terminations                                              -0.138263
# Interval since last Live Birth (Mo)                              1.000000
# Number of Prenatal Visits                                        0.053407
# Daily Cigarette use before Pregnancy                            -0.020923
# Daily Cigarette use, 1st Trimester                              -0.039529
# Daily Cigarette use, 2nd Trimester                              -0.045948
# Daily Cigarette use, 3rd Trimester                              -0.046633
# BMI                                                             -0.073239
# Weight Gain                                                      0.114452
# Number of Previous Cesareans                                    -0.293900
# 5 Minute APGAR                                                  -0.048149
# 10 Minute APGAR                                                 -0.021585
# Plurality (Number of Babies)                                    -0.107770
# Gestation Duration (wks)                                         0.067648
# Birth Weight (g)                                                -0.058627
# Maternal Education                                               0.096695
# Paternal Education                                               0.065014
# Month prenatal care Began                                       -0.006110
#
#                                       Number of Prenatal Visits  \
# Maternal Age                                           0.076356
# Paternal Age                                           0.044453
# Prior births, now living                              -0.095072
# Prior births, now dead                                -0.002496
# Prior terminations                                     0.029044
# Interval since last Live Birth (Mo)                    0.053407
# Number of Prenatal Visits                              1.000000
# Daily Cigarette use before Pregnancy                  -0.024694
# Daily Cigarette use, 1st Trimester                    -0.037966
# Daily Cigarette use, 2nd Trimester                    -0.041286
# Daily Cigarette use, 3rd Trimester                    -0.039487
# BMI                                                    0.051524
# Weight Gain                                            0.061512
# Number of Previous Cesareans                          -0.019722
# 5 Minute APGAR                                         0.017841
# 10 Minute APGAR                                        0.012227
# Plurality (Number of Babies)                           0.023453
# Gestation Duration (wks)                               0.132656
# Birth Weight (g)                                       0.116412
# Maternal Education                                     0.139681
# Paternal Education                                     0.096502
# Month prenatal care Began                             -0.104156
#
#                                       Daily Cigarette use before Pregnancy  \
# Maternal Age                                                     -0.064467
# Paternal Age                                                     -0.034659
# Prior births, now living                                          0.036369
# Prior births, now dead                                            0.012838
# Prior terminations                                                0.056671
# Interval since last Live Birth (Mo)                              -0.020923
# Number of Prenatal Visits                                        -0.024694
# Daily Cigarette use before Pregnancy                              1.000000
# Daily Cigarette use, 1st Trimester                                0.795259
# Daily Cigarette use, 2nd Trimester                                0.699805
# Daily Cigarette use, 3rd Trimester                                0.647450
# BMI                                                               0.018637
# Weight Gain                                                       0.021339
# Number of Previous Cesareans                                      0.018054
# 5 Minute APGAR                                                   -0.015447
# 10 Minute APGAR                                                  -0.006874
# Plurality (Number of Babies)                                      0.000410
# Gestation Duration (wks)                                         -0.015711
# Birth Weight (g)                                                 -0.057071
# Maternal Education                                               -0.146372
# Paternal Education                                               -0.111914
# Month prenatal care Began                                         0.006678
#
#                                       Daily Cigarette use, 1st Trimester  \
# Maternal Age                                                   -0.046485
# Paternal Age                                                   -0.018142
# Prior births, now living                                        0.057252
# Prior births, now dead                                          0.014621
# Prior terminations                                              0.056842
# Interval since last Live Birth (Mo)                            -0.039529
# Number of Prenatal Visits                                      -0.037966
# Daily Cigarette use before Pregnancy                            0.795259
# Daily Cigarette use, 1st Trimester                              1.000000
# Daily Cigarette use, 2nd Trimester                              0.875965
# Daily Cigarette use, 3rd Trimester                              0.814801
# BMI                                                             0.013486
# Weight Gain                                                    -0.002027
# Number of Previous Cesareans                                    0.025321
# 5 Minute APGAR                                                 -0.013698
# 10 Minute APGAR                                                -0.006258
# Plurality (Number of Babies)                                    0.000333
# Gestation Duration (wks)                                       -0.020462
# Birth Weight (g)                                               -0.065629
# Maternal Education                                             -0.135986
# Paternal Education                                             -0.101268
# Month prenatal care Began                                       0.008719
#
#                                       Daily Cigarette use, 2nd Trimester  ...  \
# Maternal Age                                                   -0.037085  ...
# Paternal Age                                                   -0.010087  ...
# Prior births, now living                                        0.064825  ...
# Prior births, now dead                                          0.014799  ...
# Prior terminations                                              0.053925  ...
# Interval since last Live Birth (Mo)                            -0.045948  ...
# Number of Prenatal Visits                                      -0.041286  ...
# Daily Cigarette use before Pregnancy                            0.699805  ...
# Daily Cigarette use, 1st Trimester                              0.875965  ...
# Daily Cigarette use, 2nd Trimester                              1.000000  ...
# Daily Cigarette use, 3rd Trimester                              0.933397  ...
# BMI                                                             0.011011  ...
# Weight Gain                                                    -0.012499  ...
# Number of Previous Cesareans                                    0.027721  ...
# 5 Minute APGAR                                                 -0.012414  ...
# 10 Minute APGAR                                                -0.005479  ...
# Plurality (Number of Babies)                                    0.001026  ...
# Gestation Duration (wks)                                       -0.022066  ...
# Birth Weight (g)                                               -0.066855  ...
# Maternal Education                                             -0.127527  ...
# Paternal Education                                             -0.093412  ...
# Month prenatal care Began                                       0.008380  ...
#
#                                       Weight Gain  \
# Maternal Age                            -0.032181
# Paternal Age                            -0.030735
# Prior births, now living                -0.109317
# Prior births, now dead                  -0.011331
# Prior terminations                      -0.010774
# Interval since last Live Birth (Mo)      0.114452
# Number of Prenatal Visits                0.061512
# Daily Cigarette use before Pregnancy     0.021339
# Daily Cigarette use, 1st Trimester      -0.002027
# Daily Cigarette use, 2nd Trimester      -0.012499
# Daily Cigarette use, 3rd Trimester      -0.015352
# BMI                                     -0.266392
# Weight Gain                              1.000000
# Number of Previous Cesareans            -0.035692
# 5 Minute APGAR                           0.000136
# 10 Minute APGAR                          0.004001
# Plurality (Number of Babies)             0.066132
# Gestation Duration (wks)                 0.063761
# Birth Weight (g)                         0.161330
# Maternal Education                       0.078015
# Paternal Education                       0.066414
# Month prenatal care Began               -0.011606
#
#                                       Number of Previous Cesareans  \
# Maternal Age                                              0.152332
# Paternal Age                                              0.123680
# Prior births, now living                                  0.281444
# Prior births, now dead                                    0.039829
# Prior terminations                                        0.081219
# Interval since last Live Birth (Mo)                      -0.293900
# Number of Prenatal Visits                                -0.019722
# Daily Cigarette use before Pregnancy                      0.018054
# Daily Cigarette use, 1st Trimester                        0.025321
# Daily Cigarette use, 2nd Trimester                        0.027721
# Daily Cigarette use, 3rd Trimester                        0.027407
# BMI                                                       0.121686
# Weight Gain                                              -0.035692
# Number of Previous Cesareans                              1.000000
# 5 Minute APGAR                                           -0.012978
# 10 Minute APGAR                                          -0.002753
# Plurality (Number of Babies)                              0.024054
# Gestation Duration (wks)                                 -0.070876
# Birth Weight (g)                                          0.005893
# Maternal Education                                       -0.043451
# Paternal Education                                       -0.036490
# Month prenatal care Began                                 0.003272
#
#                                       5 Minute APGAR  10 Minute APGAR  \
# Maternal Age                                0.011400         0.004774
# Paternal Age                                0.011006         0.004186
# Prior births, now living                    0.027913         0.009045
# Prior births, now dead                     -0.004518        -0.001670
# Prior terminations                         -0.004989        -0.002684
# Interval since last Live Birth (Mo)        -0.048149        -0.021585
# Number of Prenatal Visits                   0.017841         0.012227
# Daily Cigarette use before Pregnancy       -0.015447        -0.006874
# Daily Cigarette use, 1st Trimester         -0.013698        -0.006258
# Daily Cigarette use, 2nd Trimester         -0.012414        -0.005479
# Daily Cigarette use, 3rd Trimester         -0.011553        -0.005176
# BMI                                        -0.048845        -0.019902
# Weight Gain                                 0.000136         0.004001
# Number of Previous Cesareans               -0.012978        -0.002753
# 5 Minute APGAR                              1.000000         0.676668
# 10 Minute APGAR                             0.676668         1.000000
# Plurality (Number of Babies)               -0.055512        -0.017556
# Gestation Duration (wks)                    0.133478         0.065344
# Birth Weight (g)                            0.112619         0.060040
# Maternal Education                          0.013218         0.008746
# Paternal Education                          0.012229         0.007880
# Month prenatal care Began                  -0.001347        -0.001756
#
#                                       Plurality (Number of Babies)  \
# Maternal Age                                              0.046313
# Paternal Age                                              0.038391
# Prior births, now living                                  0.092996
# Prior births, now dead                                    0.005173
# Prior terminations                                        0.020863
# Interval since last Live Birth (Mo)                      -0.107770
# Number of Prenatal Visits                                 0.023453
# Daily Cigarette use before Pregnancy                      0.000410
# Daily Cigarette use, 1st Trimester                        0.000333
# Daily Cigarette use, 2nd Trimester                        0.001026
# Daily Cigarette use, 3rd Trimester                        0.000537
# BMI                                                       0.025119
# Weight Gain                                               0.066132
# Number of Previous Cesareans                              0.024054
# 5 Minute APGAR                                           -0.055512
# 10 Minute APGAR                                          -0.017556
# Plurality (Number of Babies)                              1.000000
# Gestation Duration (wks)                                 -0.224221
# Birth Weight (g)                                         -0.263188
# Maternal Education                                        0.017320
# Paternal Education                                        0.014743
# Month prenatal care Began                                -0.001878
#
#                                       Gestation Duration (wks)  \
# Maternal Age                                         -0.051283
# Paternal Age                                         -0.038865
# Prior births, now living                             -0.072662
# Prior births, now dead                               -0.019735
# Prior terminations                                   -0.043521
# Interval since last Live Birth (Mo)                   0.067648
# Number of Prenatal Visits                             0.132656
# Daily Cigarette use before Pregnancy                 -0.015711
# Daily Cigarette use, 1st Trimester                   -0.020462
# Daily Cigarette use, 2nd Trimester                   -0.022066
# Daily Cigarette use, 3rd Trimester                   -0.020950
# BMI                                                  -0.042848
# Weight Gain                                           0.063761
# Number of Previous Cesareans                         -0.070876
# 5 Minute APGAR                                        0.133478
# 10 Minute APGAR                                       0.065344
# Plurality (Number of Babies)                         -0.224221
# Gestation Duration (wks)                              1.000000
# Birth Weight (g)                                      0.455496
# Maternal Education                                    0.035968
# Paternal Education                                    0.033609
# Month prenatal care Began                            -0.011329
#
#                                       Birth Weight (g)  Maternal Education  \
# Maternal Age                                  0.041514            0.398882
# Paternal Age                                  0.026678            0.274357
# Prior births, now living                      0.029535           -0.197251
# Prior births, now dead                       -0.011635           -0.026450
# Prior terminations                           -0.019077           -0.019344
# Interval since last Live Birth (Mo)          -0.058627            0.096695
# Number of Prenatal Visits                     0.116412            0.139681
# Daily Cigarette use before Pregnancy         -0.057071           -0.146372
# Daily Cigarette use, 1st Trimester           -0.065629           -0.135986
# Daily Cigarette use, 2nd Trimester           -0.066855           -0.127527
# Daily Cigarette use, 3rd Trimester           -0.064024           -0.121477
# BMI                                           0.067262           -0.124302
# Weight Gain                                   0.161330            0.078015
# Number of Previous Cesareans                  0.005893           -0.043451
# 5 Minute APGAR                                0.112619            0.013218
# 10 Minute APGAR                               0.060040            0.008746
# Plurality (Number of Babies)                 -0.263188            0.017320
# Gestation Duration (wks)                      0.455496            0.035968
# Birth Weight (g)                              1.000000            0.071774
# Maternal Education                            0.071774            1.000000
# Paternal Education                            0.054631            0.632689
# Month prenatal care Began                    -0.009787           -0.042546
#
#                                       Paternal Education  \
# Maternal Age                                    0.316331
# Paternal Age                                    0.250323
# Prior births, now living                       -0.136074
# Prior births, now dead                         -0.019930
# Prior terminations                             -0.014944
# Interval since last Live Birth (Mo)             0.065014
# Number of Prenatal Visits                       0.096502
# Daily Cigarette use before Pregnancy           -0.111914
# Daily Cigarette use, 1st Trimester             -0.101268
# Daily Cigarette use, 2nd Trimester             -0.093412
# Daily Cigarette use, 3rd Trimester             -0.088685
# BMI                                            -0.166371
# Weight Gain                                     0.066414
# Number of Previous Cesareans                   -0.036490
# 5 Minute APGAR                                  0.012229
# 10 Minute APGAR                                 0.007880
# Plurality (Number of Babies)                    0.014743
# Gestation Duration (wks)                        0.033609
# Birth Weight (g)                                0.054631
# Maternal Education                              0.632689
# Paternal Education                              1.000000
# Month prenatal care Began                      -0.028213
#
#                                       Month prenatal care Began
# Maternal Age                                          -0.019011
# Paternal Age                                          -0.008936
# Prior births, now living                               0.020914
# Prior births, now dead                                 0.003921
# Prior terminations                                    -0.002778
# Interval since last Live Birth (Mo)                   -0.006110
# Number of Prenatal Visits                             -0.104156
# Daily Cigarette use before Pregnancy                   0.006678
# Daily Cigarette use, 1st Trimester                     0.008719
# Daily Cigarette use, 2nd Trimester                     0.008380
# Daily Cigarette use, 3rd Trimester                     0.007707
# BMI                                                   -0.003340
# Weight Gain                                           -0.011606
# Number of Previous Cesareans                           0.003272
# 5 Minute APGAR                                        -0.001347
# 10 Minute APGAR                                       -0.001756
# Plurality (Number of Babies)                          -0.001878
# Gestation Duration (wks)                              -0.011329
# Birth Weight (g)                                      -0.009787
# Maternal Education                                    -0.042546
# Paternal Education                                    -0.028213
# Month prenatal care Began                              1.000000
#
# [22 rows x 22 columns]

# %%
sns.set(rc={'figure.figsize':(30,30)})
sns.heatmap(corrMatrix, annot=True)
plt.show()

# %% [markdown]
# Correlated variables with high correlation include cigarette use before pregnancy and use at various trimesters during the pregnancy. Upon closer examination, it looks like cigarette use during the 3rd trimester is negatively correlated with birth weight , duration of pregnancy and the 10 minute APGAR (a measure of newborn health imediately after birth).
# I will consider this when performing feature selection, potentially dropping cigarette use before pregnancy and during the 1st and 2nd trimester.
#
# There is a high correlation between age and educational attainment. I will leave them both in for now and consider combining them during feature engineering.
#
# Prior births now living is very negatively correlated with the amount of time since last live birth. 5 minute APGAR is highly correlated with 10 minute APGAR (As one might expect), meaning only one of these two measures are really necessary to include. I will drop the 10 minute APGAR since this occurs later.
#
# Gestation duration, birth weight, and plurality are all moderately related to eachother, as one might expect. I will consider combining or dropping all but birth weight as outcome indicators.
#
# Number of Cesarian sections is related to maternal age, number of prior births now living, and negatively correlated with months since last live birth. These relationships are moderate and I will consider them during feature engineering.

# %%
dropVars = ['Daily Cigarette use before Pregnancy','Daily Cigarette use, 1st Trimester','Payment Source',
                         'Fetal Presentation at Delivery',
            'Daily Cigarette use, 2nd Trimester','10 Minute APGAR','Paternal Race', 'Paternal Hispanic Origin', 'Maternal Hispanic Origin', ]

df.drop(dropVars, axis =1, inplace = True)

# %%
#reset groups without dropped variables
Binary_Categoricals = ['Maternal Nativity','Paternity Acknowledged', 'WIC','Pre-pregnancy Diabetes', 
                      'Gestational Diabetes', 'Pre-pregnancy Hypertension', 'Gestational Hypertension',
                      'Hypertension Eclampsia', 'Previous Preterm Birth','Infertility treatment used', 'Fertility Enhancing Drugs', 
                      'Asst. Reproductive Tech', 'Gonorrhea', 'Syphilis', 'Chlamydia', 'Hep B', 'Hep C',
                      'Successful External Cephalic Version', 'Failed Cephalic Version','Induced Labor', 'Augmented Labor', 
                      'Steroids', 'Antibiotics', 'Chorioamnionitis', 'Anesthesia','If Cesarean, Labor Attempted',
                      'Maternal Transfusion', 'Perineal Laceration', 'Ruptured Uterus', 'Unplanned Hysterectomy',
                      'Maternal admit to ICU', 'Mother Transferred','infant sex','Assisted Ventilation immediately',
                      'Assisted ventilation >6hr', 'Admission to NICU', 'Surffactant', 'Antibiotis for Newborn', 'Seizures',
                      'Anencephaly', 'Spina Bifida', 'Cyanotic Congenital Heart Disease', 'Congenital Diaphragmatic Hernia',
                      'Omphalocele', 'Gastroschisis', 'Limb Reduction Defect', 'Cleft lip', 'Cleft Palate',  'Hypospadias', 'Infant Transferred', 'Infant Living', 'Infant Breastfed']
Ordered_Categoricals = ['Maternal Education','Paternal Education','Month prenatal care Began']
Unordered_Categoricals = ['Birth Place','Marital Status','Maternal Residence Status','Maternal Race','Maternal Hispanic Origin', 
                         'Paternal Race', 'Paternal Hispanic Origin', 'Fetal Presentation at Delivery','Delivery Method',
                         'Attendant at Birth','Payment Source','Down Syndrome', 'Suspected Chromosomal Disorder']
Numeric = ['Maternal Age','Paternal Age','Prior births, now living', 'Prior births, now dead', 'Prior terminations',
          'Interval since last Live Birth (Mo)', 'Number of Prenatal Visits', 'Daily Cigarette use, 3rd Trimester',
          'BMI', 'Weight Gain', 'Number of Previous Cesareans','5 Minute APGAR', 'Plurality (Number of Babies)',
          'Gestation Duration (wks)', 'Birth Weight (g)']

# %% [markdown]
# #### Next Step: Feature Encoding

# %% [markdown]
# ## Note:
#
# Due to processing limitations, I will test methods using a subset of the dataframe first, then train on the whole dataframe in the technical notebook.

# %%
df1 = df.sample(frac = 
               .01)
df1.reset_index(drop=True, inplace =True)
df1 = df1[Numeric+Ordered_Categoricals+Unordered_Categoricals]
df2 = df1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-d28149dae00e> in <module>
#       2                .01)
#       3 df1.reset_index(drop=True, inplace =True)
# ----> 4 df1 = df1[Numeric+Ordered_Categoricals+Unordered_Categoricals]
#       5 df2 = df1
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1550             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1551
# -> 1552         self._validate_read_indexer(
#    1553             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1554         )
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1644             if not (self.name == "loc" and not raise_missing):
#    1645                 not_found = list(set(key) - set(ax))
# -> 1646                 raise KeyError(f"{not_found} not in index")
#    1647
#    1648             # we skip the warning on Categorical/Interval
#
# KeyError: "['Payment Source', 'Maternal Hispanic Origin', 'Paternal Race', 'Paternal Hispanic Origin', 'Fetal Presentation at Delivery'] not in index"

# %%
#drop variables from unordered categoricals identified below
df1.drop(['Maternal Hispanic Origin', 'Paternal Race', 'Paternal Hispanic Origin', 'Fetal Presentation at Delivery','Delivery Method',
                         'Attendant at Birth'],axis=1,inplace = True)
new_unordered = ['Birth Place','Marital Status','Maternal Race', 'Payment Source']

# %%
df1.shape

# %%
df1.reset_index(drop = True, inplace = True)

# %%
#first I will encode the binary and ordered categorical data
le = LabelEncoder()

for i in (Ordered_Categoricals+Binary_Categoricals):
    df1[i] = le.fit_transform(df1[i])

# %%
# Bring in function from .py file
# %run Functions_HW2.py

# %%
ohedf = onehotencoder(df1, new_unordered)
ohedf

# %%
corrMatrix = ohedf.corr()
sns.set(rc={'figure.figsize':(30,30)})
sns.heatmap(corrMatrix, annot=True)
plt.show()

# %% [markdown]
# Maternal race and paternal race are highly correlated, so I will use only maternal race. I will also leave out maternal hispanic origin, as that also overlaps heavily with race. Finally, delivery method seems to be correlated with payment source, and so I will drop out deliver method as well.

# %%
df1 = df1.join(ohedf)
df1.drop(new_unordered,axis=1,inplace = True) #replacing the unordered categoricals with the encoded data

# %% [markdown]
# Okay! My categorical features are encoded. Next I will scale the features before doing running a clustering algorithm on the complete dataset. The main reason to scale data for clustering is so that one feature doesn't inordinately influence the model because of a wider range of data. I will normalize, so that all the data is on a scale from 0 to 1.

# %%
df1.drop(Binary_Categoricals,axis=1,inplace = True)
corrMatrix = df1.corr()
sns.set(rc={'figure.figsize':(30,30)})
sns.heatmap(corrMatrix, annot=True)
plt.show()

# %%
scaler = MinMaxScaler()
scaler.fit(df1)
df_scaled = scaler.transform(df1)

# %% [markdown]
# Now I can apply a clustering algorithm to the data and see what is uncovered! I am going to start with a KMeans to see if the data have any obvious clusters, but I think the best algoithm for this will be the DBSCAN (Density-Based Spatial Clustering of Applications with Noise) algorithm. DBSCAN uses a threshold epsilon to indicate the neighbors that are considered part of the cluster. DBSCAN corepoints (the center of the cluster) is determined by the least min_sample points (min_sample being the minimum number of neighbors required to be considered a corepoint).
#
# The reason I am focusing on DBSCAN is multimodal:
# 1. The nature of the data I am using is very large, and the DBSCAN model is capable of handling large datasets efficiently
# 2. DBSCAN handles noise, and this dataset contains a lot of noise and overlapping groups
# 3. DBSCAN is able to handle oddly shaped clusters, while other methods, like KMeans, are limited to circular clusters.
#
# Drawbacks of the DBSCAN model are that if the clusters have differing densities, they are not detected well.
#
# I used information from
# https://www.kdnuggets.com/2019/10/right-clustering-algorithm.html,
# https://www.datanovia.com/en/lessons/dbscan-density-based-clustering-essentials/#:~:text=Two%20important%20parameters%20are%20required,neighbors%20within%20%E2%80%9Ceps%E2%80%9D%20radius and
# https://towardsdatascience.com/machine-learning-clustering-dbscan-determine-the-optimal-value-for-epsilon-eps-python-example-3100091cfbc to help me decide on the algorithm to use and to understand the rationale for the DBSCAN model.

# %%
from sklearn.cluster import KMeans 
from sklearn import metrics

# %%
from yellowbrick.cluster import KElbowVisualizer

# Instantiate the clustering model and visualizer
model = KMeans()

visualizer = KElbowVisualizer(model, k=(2,50), metric = 'calinski_harabasz', timings=False)

visualizer.fit(df_scaled)        # Fit the data to the visualizer
visualizer.show()

# %% [raw]
# As I expected, no obvious clusters where identified in the data using the KMeans method. I will proceed to see if I can identify clusters using DBSCAN.

# %%
from sklearn.neighbors import NearestNeighbors
from sklearn.cluster import DBSCAN

# %%
neigh = NearestNeighbors(n_neighbors=2)
nbrs = neigh.fit(df_scaled)
distances, indices = nbrs.kneighbors(df_scaled)

# %%
distances = np.sort(distances, axis=0)
distances = distances[:,1]
plt.plot(distances)

# %%
m = DBSCAN(eps=.3, min_samples=75*2, n_jobs=-1) #Eps should be based on the graph above, but the size means that the function will take a long time to run, so I chose to keep it small, min_samples is base on the rule of thumb minPts = 2·dim
m.fit(df_scaled)

# %%
labels = m.labels_

n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
print('Estimated number of clusters: %d' % n_clusters_)

# %% [markdown]
# The above model performed extremely poorly and I suspect that is in part due to the binary variables which are hot encoded and many of which are heavily biased towards 0 (because they indicate rare conditions). Since no clusters were identified, I will attempt to make some adjustments.
#
# I will drop the binary and keep only the Numerics (like birth weight, parental aged, etc.) unordered and ordered categoricals (like parental educational attainment).

# %%
df1 = df.sample(frac = 
               .01)
df1.reset_index(drop=True, inplace =True)
df1 = df1[Numeric+Ordered_Categoricals+Unordered_Categoricals]
df2 = df1

# %%
le = LabelEncoder()

for i in (Ordered_Categoricals):
    le.fit(df1[i])
    df1[i] = le.transform(df1[i])
df1.head()

# %%
ohedf = onehotencoder(df1, Unordered_Categoricals)
ohedf

# %%
df1 = df1.join(ohedf)
df1.drop(Unordered_Categoricals,axis=1,inplace = True) 
df2 = df1.drop(sanity_check, axis=1)

# %%
df2.info()

# %%
#ohedf = onehotencoder(df1, Unordered_Categoricals)
#df2 = df2.join(ohedf)
#df2.drop(Unordered_Categoricals,axis=1,inplace = True) #replacing the unordered categoricals with the encoded data
#df2.drop(Binary_Categoricals, axis=1, inplace = True) #dropping binary categoricals

# %%
scaler = MinMaxScaler()
scaler.fit(df2)
df_scaled = scaler.transform(df2)

# %%
neigh = NearestNeighbors(n_neighbors=2)
nbrs = neigh.fit(df_scaled)
distances, indices = nbrs.kneighbors(df_scaled)
distances = np.sort(distances, axis=0)
distances = distances[:,1]
plt.plot(distances)

# %%
m = DBSCAN(eps=.3, min_samples=89*2, n_jobs=-1) #Eps is based on the graph above, min_samples is base on the rule of thumb minPts = 2·dim
m.fit(df_scaled)
core_samples_mask = np.zeros_like(m.labels_, dtype=bool)
core_samples_mask[m.core_sample_indices_] = True
labels = m.labels_

# Number of clusters in labels, ignoring noise if present.
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
n_noise_ = list(labels).count(-1)

print('Estimated number of clusters: %d' % n_clusters_)
print('Estimated number of noise points: %d' % n_noise_)
print("Silhouette Coefficient: %0.3f"
      % metrics.silhouette_score(df_scaled, labels)) #https://medium.com/@shritam/how-dbscan-algorithm-works-2b5bef80fb3

# %%
colors = ['royalblue', 'maroon', 'forestgreen', 'mediumorchid', 'tan', 'deeppink', 'olive', 'goldenrod', 'lightcyan', 'navy']
vectorizer = np.vectorize(lambda x: colors[x % len(colors)])

# %%
clusters = m.labels_
plt.scatter(df_scaled[:,0], df_scaled[:,1], c=vectorizer(clusters))

# %% [markdown]
# This produces a much better model than when the binary variables aren't included!
#
# Next I will use PCA to identify the variables responsible for the majority of the variance in order to reduce the dimensionality of the dataset. I will then proceed with the DBSPAN clustering algorithm.

# %%
pca = PCA(n_components=.95)
principal_components = pca.fit_transform(df_scaled)
len(pca.components_)

# %%
# https://towardsdatascience.com/dive-into-pca-principal-component-analysis-with-python-43ded13ead21

principal_df = pd.DataFrame(data = principal_components)
print(principal_df.shape)

# %%
neigh = NearestNeighbors(n_neighbors=2)
nbrs = neigh.fit(principal_df)
distances, indices = nbrs.kneighbors(principal_df)

# %%
distances = np.sort(distances, axis=0)
distances = distances[:,1]
plt.plot(distances)

# %%
m = DBSCAN(eps=.25, min_samples=20, n_jobs=-1) #based on the elbow in the plot, eps is set at .25
m.fit(principal_df)

# %%
core_samples_mask = np.zeros_like(m.labels_, dtype=bool)
core_samples_mask[m.core_sample_indices_] = True
labels = m.labels_

# Number of clusters in labels, ignoring noise if present.
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
n_noise_ = list(labels).count(-1)

print('Estimated number of clusters: %d' % n_clusters_)
print('Estimated number of noise points: %d' % n_noise_)
print("Silhouette Coefficient: %0.3f"
      % metrics.silhouette_score(principal_df, labels)) #https://medium.com/@shritam/how-dbscan-algorithm-works-2b5bef80fb3

# %% [markdown]
# Note: the silhouette coeeficient decreased with PCA feature selection and the number of clusters remained the same meaning there was more overelap in clusters when dimensions were removed

# %%
clusters = m.labels_

# %%
plt.scatter(principal_df.iloc[:,0], principal_df.iloc[:,1], c=vectorizer(clusters))

# %%
#Finally, I want to identify some of the characteristics of my clusters:
clusters = m.fit_predict(principal_df)
df1['cluster'] = clusters

# %%
clusters_grouped = df1.groupby(by = ['cluster']).var()
#I am only interested in when the clusters are different, so I will drop columns where all the data is the same
clusters_grouped.drop(clusters_grouped.std()[(clusters_grouped.std() == 0)].index, axis=1)

# %%
pd.set_option('display.max_rows', df1.shape[0]+1)

# %%
clusters_grouped = df1.groupby(by = ['cluster']).var()
#I am only interested in when the clusters are different, so I will drop columns where all the data is the same
clusters_grouped.drop(clusters_grouped.std()[(clusters_grouped.std() == 0)].index, axis=1).T

# %% [markdown]
# ## Conclusions:
# After dimensionality reduction, there appear to be 3 clusters in the data. Upon closer analysis of the differences between those clusters, I found that parental age, prior births, birth weight, maternal BMI,and parental education were among the features that most varied among groups. These data can be used to now target those populations most at risk of a negative outcome, for example, the cluster with the highest parental ages also had higher APGAR5 scores, indicating poorer health indicators for the infant after birth.
#
# Additional analysis may be required to tease out the nuances of the groups and discover additional targets for intervension.
#
# Using this project I was able to gain experience applying a clustering algorithm as well as working with a larger, more complex dataset than I am used to. I was able to gain a better understanding of PCA and how to apply it practically, as well as what DBSCAN is, when it is best applied, and how to determine the values for each of the parameters. I feel that I have gained a lot through this project in terms of experience and practice.

# %%
end_time = time.time()

print('Runtime: '+ str((end_time - start_time)/60) + ' minutes')
